# %%
import pandas as pd

# %%
# %config Completer.use_jedi = False
# Out:
# /home/bwood/anaconda3/envs/jup1/lib/python3.5/site-packages/ipykernel_launcher.py:1: UserWarning: Config option `use_jedi` not recognized by `IPCompleter`.
#   """Entry point for launching an IPython kernel.

# %%
data2 = pd.read_excel("Financial Sample.xlsx")
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-24-34204cc3eef3> in <module>()
# ----> 1 data2 = pd.read_excel("Financial Sample.xlsx")
#
# /home/bwood/anaconda3/envs/jup1/lib/python3.5/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# /home/bwood/anaconda3/envs/jup1/lib/python3.5/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ...

# %%
sales = pd.read_csv("100 Sales Records.csv")

# %%
type(sales)
# Out:
# pandas.core.frame.DataFrame

# %%
sales.head(5)
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
sales['Units Sold'].head(2)
# Out:
# 0    9925
# 1    2804
# Name: Units Sold, dtype: int64

# %%
sales.Region.head(2)
# Out:
# 0                Australia and Oceania
# 1    Central America and the Caribbean
# Name: Region, dtype: object

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6a4642092433> in <module>()
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
sales.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
sales.columns = sales.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
sales.columns
# Out:
# Index(['region', 'country', 'item_type', 'sales_channel', 'order_priority',
#        'order_date', 'order_id', 'ship_date', 'units_sold', 'unit_price',
#        'unit_cost', 'total_revenue', 'total_cost', 'total_profit'],
#       dtype='object')

# %%
sales.units_sold.head(2)
# Out:
# 0    9925
# 1    2804
# Name: units_sold, dtype: int64

# %%
df_data=[[1900, '1-4 Years', 1983.8],[1901, '1-4 Years', 1695.0]]
df_columns=['Year', 'Age Group', 'Death Rate']

# %%
scratch = pd.DataFrame(data=df_data,columns=df_columns)

# %%
scratch
# Out:
#    Year  Age Group  Death Rate
# 0  1900  1-4 Years      1983.8
# 1  1901  1-4 Years      1695.0

# %%
# %whos
# Out:
# Variable     Type         Data/Info
# -----------------------------------
# df_columns   list         n=3
# df_data      list         n=2
# pd           module       <module 'pandas' from '/h<...>ages/pandas/__init__.py'>
# sales        DataFrame                             <...>\n[100 rows x 14 columns]
# scratch      DataFrame       Year  Age Group  Death<...>01  1-4 Years      1695.0

# %%
scratch.to_pickle("small_set.pkl")

# %%
scratch2 = pd.read_pickle("small_set.pkl")

# %%
scratch2
# Out:
#    Year  Age Group  Death Rate
# 0  1900  1-4 Years      1983.8
# 1  1901  1-4 Years      1695.0

# %%
sales.values
# Out:
# array([['Australia and Oceania', 'Tuvalu', 'Baby Food', ..., 2533654.0,
#         1582243.5, 951410.5],
#        ['Central America and the Caribbean', 'Grenada', 'Cereal', ...,
#         576782.8, 328376.44, 248406.36],
#        ['Europe', 'Russia', 'Office Supplies', ..., 1158502.59,
#         933903.84, 224598.75],
#        ...,
#        ['Sub-Saharan Africa', 'Sierra Leone', 'Vegetables', ...,
#         228779.1, 135031.05, 93748.05],
#        ['North America', 'Mexico', 'Personal Care', ..., 471336.91,
#         326815.89, 144521.02],
#        ['Sub-Saharan Africa', 'Mozambique', 'Household', ..., 3586605.09,
#         2697132.18, 889472.91]], dtype=object)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
# region            100 non-null object
# country           100 non-null object
# item_type         100 non-null object
# sales_channel     100 non-null object
# order_priority    100 non-null object
# order_date        100 non-null object
# order_id          100 non-null int64
# ship_date         100 non-null object
# units_sold        100 non-null int64
# unit_price        100 non-null float64
# unit_cost         100 non-null float64
# total_revenue     100 non-null float64
# total_cost        100 non-null float64
# total_profit      100 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 11.0+ KB

# %%
print("Index: ", sales.index)
print("Columns:", sales.columns)
print("Size: ", sales.size)
print("Shape: ", sales.shape)
# Out:
# Index:  RangeIndex(start=0, stop=100, step=1)
# Columns: Index(['region', 'country', 'item_type', 'sales_channel', 'order_priority',
#        'order_date', 'order_id', 'ship_date', 'units_sold', 'unit_price',
#        'unit_cost', 'total_revenue', 'total_cost', 'total_profit'],
#       dtype='object')
# Size:  1400
# Shape:  (100, 14)

# %%
sales.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 14 columns):
# region            100 non-null object
# country           100 non-null object
# item_type         100 non-null object
# sales_channel     100 non-null object
# order_priority    100 non-null object
# order_date        100 non-null object
# order_id          100 non-null int64
# ship_date         100 non-null object
# units_sold        100 non-null int64
# unit_price        100 non-null float64
# unit_cost         100 non-null float64
# total_revenue     100 non-null float64
# total_cost        100 non-null float64
# total_profit      100 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 51.1 KB

# %%
sales.head(5)
# Out:
#                               region                country        item_type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   sales_channel order_priority order_date   order_id  ship_date  units_sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %%
sales.country.nunique()
# Out:
# 76

# %%
sales.country.count()
# Out:
# 100

# %%
sales.units_sold.describe()
# Out:
# count     100.000000
# mean     5128.710000
# std      2794.484562
# min       124.000000
# 25%      2836.250000
# 50%      5382.500000
# 75%      7369.000000
# max      9925.000000
# Name: units_sold, dtype: float64

# %%
sales[['units_sold', 'unit_price']].head(10)
# Out:
#    units_sold  unit_price
# 0        9925      255.28
# 1        2804      205.70
# 2        1779      651.21
# 3        8102        9.33
# 4        5062      651.21
# 5        2974      255.28
# 6        4187      668.27
# 7        8082      154.06
# 8        6070       81.73
# 9        6593      205.70

# %%
sales.head(2)
# Out:
#                               region  country  item_type sales_channel  \
# 0              Australia and Oceania   Tuvalu  Baby Food       Offline
# 1  Central America and the Caribbean  Grenada     Cereal        Online
#
#   order_priority order_date   order_id  ship_date  units_sold  unit_price  \
# 0              H  5/28/2010  669165933  6/27/2010        9925      255.28
# 1              C  8/22/2012  963881480  9/15/2012        2804      205.70
#
#    unit_cost  total_revenue  total_cost  total_profit
# 0     159.42      2533654.0  1582243.50     951410.50
# 1     117.11       576782.8   328376.44     248406.36

# %%
# Get all sales with the order priority being "H"

# %% [markdown]
# # These are filter commands

# %% [markdown]
# ## How to access OOP method.

# %%
sales.query('order_priority == "H"').unit_cost.max()
# Out:
# 524.96

# %% [markdown]
# ## Access using indexes.

# %%
sales.query('order_priority == "H"')['unit_cost'].max()
# Out:
# 524.96

# %%
sales.iloc[4:7,1:3]
# Out:
#            country        item_type
# 4           Rwanda  Office Supplies
# 5  Solomon Islands        Baby Food
# 6           Angola        Household

# %%
x = sales.iloc[4:7,1:3]

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
scratch2
# Out:
#    Year  Age Group  Death Rate
# 0  1900  1-4 Years      1983.8
# 1  1901  1-4 Years      1695.0

# %%
scratch
# Out:
#    Year  Age Group  Death Rate
# 0  1900  1-4 Years      1983.8
# 1  1901  1-4 Years      1695.0

# %%
sales.sort_values('units_sold').head(5)
# Out:
#                           region         country      item_type sales_channel  \
# 10                          Asia      Kyrgyzstan     Vegetables        Online
# 43                        Europe        Slovakia     Vegetables        Online
# 47                        Europe     Switzerland  Personal Care        Online
# 58                        Europe  United Kingdom      Household        Online
# 88  Middle East and North Africa          Kuwait         Fruits        Online
#
#    order_priority  order_date   order_id   ship_date  units_sold  unit_price  \
# 10              H   6/24/2011  814711606   7/12/2011         124      154.06
# 43              H   10/6/2012  759224212  11/10/2012         171      154.06
# 47              M  12/23/2010  617667090   1/31/2011         273       81.73
# 58              L    1/5/2012  955357205   2/14/2012         282      668.27
# 88              M   4/30/2012  513417565   5/18/2012         522        9.33
#
# ...

# %%
sales_sorted = sales.sort_values('units_sold', ascending=False)

# %%
sales_sorted.head(5)
# Out:
#                           region   country  item_type sales_channel  \
# 0          Australia and Oceania    Tuvalu  Baby Food       Offline
# 56         Australia and Oceania      Fiji    Clothes       Offline
# 74  Middle East and North Africa  Pakistan  Cosmetics       Offline
# 79         Australia and Oceania    Samoa   Cosmetics        Online
# 51            Sub-Saharan Africa   Lesotho     Fruits        Online
#
#    order_priority order_date   order_id  ship_date  units_sold  unit_price  \
# 0               H  5/28/2010  669165933  6/27/2010        9925      255.28
# 56              C  6/30/2010  647876489   8/1/2010        9905      109.28
# 74              L   7/5/2013  231145322  8/16/2013        9892      437.20
# 79              H  7/20/2013  670854651   8/7/2013        9654      437.20
# 51              L  8/18/2013  918419539  9/18/2013        9606        9.33
#
#     unit_cost  total_revenue  total_cost  total_profit
# ...

# %%
sales.item_type.value_counts()
# Out:
# Cosmetics          13
# Clothes            13
# Office Supplies    12
# Fruits             10
# Personal Care      10
# Household           9
# Beverages           8
# Cereal              7
# Baby Food           7
# Vegetables          6
# Snacks              3
# Meat                2
# Name: item_type, dtype: int64

# %%
sales.units_sold.quantile([.1, .9])
# Out:
# 0.1    1235.6
# 0.9    8677.8
# Name: units_sold, dtype: float64

# %%
sales.head(20)
# Out:
#                                region                country        item_type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 5               Australia and Oceania        Solomon Islands        Baby Food
# 6                  Sub-Saharan Africa                 Angola        Household
# 7                  Sub-Saharan Africa           Burkina Faso       Vegetables
# 8                  Sub-Saharan Africa  Republic of the Congo    Personal Care
# 9                  Sub-Saharan Africa                Senegal           Cereal
# 10                               Asia             Kyrgyzstan       Vegetables
# ...

# %%
sales.country.replace({'Russia':'USSR'},inplace=True)

# %%
sales.query('country == "USSR"')
# Out:
#    region country        item_type sales_channel order_priority order_date  \
# 2  Europe    USSR  Office Supplies       Offline              L   5/2/2014
#
#     order_id ship_date  units_sold  unit_price  unit_cost  total_revenue  \
# 2  341417157  5/8/2014        1779      651.21     524.96     1158502.59
#
#    total_cost  total_profit
# 2   933903.84     224598.75

# %%
mrates = pd.read_csv("https://data.cdc.gov/api/views/v6ab-adf5/rows.csv?accessType=DOWNLOAD")

# %%
mrates
# Out:
#      Year    Age Group  Death Rate
# 0    1900    1-4 Years      1983.8
# 1    1901    1-4 Years      1695.0
# 2    1902    1-4 Years      1655.7
# 3    1903    1-4 Years      1542.1
# 4    1904    1-4 Years      1591.5
# 5    1905    1-4 Years      1498.9
# 6    1906    1-4 Years      1580.0
# 7    1907    1-4 Years      1468.3
# 8    1908    1-4 Years      1396.8
# 9    1909    1-4 Years      1348.9
# 10   1910    1-4 Years      1397.3
# 11   1911    1-4 Years      1176.0
# 12   1912    1-4 Years      1094.1
# 13   1913    1-4 Years      1193.4
# 14   1914    1-4 Years      1024.2
# 15   1915    1-4 Years       924.2
# 16   1916    1-4 Years      1111.5
# 17   1917    1-4 Years      1066.0
# 18   1918    1-4 Years      1573.5
# 19   1919    1-4 Years       928.0
# 20   1920    1-4 Years       987.2
# 21   1921    1-4 Years       801.2
# 22   1922    1-4 Years       742.0
# 23   1923    1-4 Years       806.7
# 24   1924    1-4 Years       683.2
# 25   1925    1-4 Years       641.0
# ...

# %%
mrates['MeanCentered'] = mrates['Death Rate'] - mrates['Death Rate'].mean()

# %%
mrates
# Out:
#      Year    Age Group  Death Rate
# 0    1900    1-4 Years      1983.8
# 1    1901    1-4 Years      1695.0
# 2    1902    1-4 Years      1655.7
# 3    1903    1-4 Years      1542.1
# 4    1904    1-4 Years      1591.5
# 5    1905    1-4 Years      1498.9
# 6    1906    1-4 Years      1580.0
# 7    1907    1-4 Years      1468.3
# 8    1908    1-4 Years      1396.8
# 9    1909    1-4 Years      1348.9
# 10   1910    1-4 Years      1397.3
# 11   1911    1-4 Years      1176.0
# 12   1912    1-4 Years      1094.1
# 13   1913    1-4 Years      1193.4
# 14   1914    1-4 Years      1024.2
# 15   1915    1-4 Years       924.2
# 16   1916    1-4 Years      1111.5
# 17   1917    1-4 Years      1066.0
# 18   1918    1-4 Years      1573.5
# 19   1919    1-4 Years       928.0
# 20   1920    1-4 Years       987.2
# 21   1921    1-4 Years       801.2
# 22   1922    1-4 Years       742.0
# 23   1923    1-4 Years       806.7
# 24   1924    1-4 Years       683.2
# 25   1925    1-4 Years       641.0
# ...

# %%
mrates["Aver"] = mrates["Death Rate"].mean()

# %%
mrates
# Out:
#      Year    Age Group  Death Rate  MeanCentered       Aver
# 0    1900    1-4 Years      1983.8    1790.87584  192.92416
# 1    1901    1-4 Years      1695.0    1502.07584  192.92416
# 2    1902    1-4 Years      1655.7    1462.77584  192.92416
# 3    1903    1-4 Years      1542.1    1349.17584  192.92416
# 4    1904    1-4 Years      1591.5    1398.57584  192.92416
# 5    1905    1-4 Years      1498.9    1305.97584  192.92416
# 6    1906    1-4 Years      1580.0    1387.07584  192.92416
# 7    1907    1-4 Years      1468.3    1275.37584  192.92416
# 8    1908    1-4 Years      1396.8    1203.87584  192.92416
# 9    1909    1-4 Years      1348.9    1155.97584  192.92416
# 10   1910    1-4 Years      1397.3    1204.37584  192.92416
# 11   1911    1-4 Years      1176.0     983.07584  192.92416
# 12   1912    1-4 Years      1094.1     901.17584  192.92416
# 13   1913    1-4 Years      1193.4    1000.47584  192.92416
# 14   1914    1-4 Years      1024.2     831.27584  192.92416
# ...

# %%
rates_wide = mrates.pivot(index='Year', columns='Age Group', values='Death Rate')

# %%
rates_wide.head(5)
# Out:
# Age Group  1-4 Years  10-14 Years  15-19 Years  5-9 Years
# Year
# 1900          1983.8        298.3        484.8      466.1
# 1901          1695.0        273.6        454.4      427.6
# 1902          1655.7        252.5        421.5      403.3
# 1903          1542.1        268.2        434.1      414.7
# 1904          1591.5        305.2        471.4      425.0

# %%
rates_wide[Year]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-31c18efa3cd3> in <module>()
# ----> 1 rates_wide[Year]
#
# NameError: name 'Year' is not defined

# %%
flattened = pd.DataFrame(rates_wide.to_records())

# %%
flattened.head(10)
# Out:
#    Year  1-4 Years  10-14 Years  15-19 Years  5-9 Years
# 0  1900     1983.8        298.3        484.8      466.1
# 1  1901     1695.0        273.6        454.4      427.6
# 2  1902     1655.7        252.5        421.5      403.3
# 3  1903     1542.1        268.2        434.1      414.7
# 4  1904     1591.5        305.2        471.4      425.0
# 5  1905     1498.9        279.8        439.3      396.3
# 6  1906     1580.0        272.2        445.2      377.4
# 7  1907     1468.3        265.8        437.7      365.6
# 8  1908     1396.8        247.9        397.7      354.2
# 9  1909     1348.9        230.5        363.6      330.2

# %%
flattened.Year
# Out:
# 0      1900
# 1      1901
# 2      1902
# 3      1903
# 4      1904
# 5      1905
# 6      1906
# 7      1907
# 8      1908
# 9      1909
# 10     1910
# 11     1911
# 12     1912
# 13     1913
# 14     1914
# 15     1915
# 16     1916
# 17     1917
# 18     1918
# 19     1919
# 20     1920
# 21     1921
# 22     1922
# 23     1923
# 24     1924
# 25     1925
# 26     1926
# 27     1927
# 28     1928
# 29     1929
#        ...
# 89     1989
# 90     1990
# 91     1991
# 92     1992
# 93     1993
# 94     1994
# 95     1995
# 96     1996
# 97     1997
# 98     1998
# 99     1999
# 100    2000
# 101    2001
# 102    2002
# 103    2003
# 104    2004
# 105    2005
# 106    2006
# 107    2007
# 108    2008
# 109    2009
# 110    2010
# 111    2011
# 112    2012
# 113    2013
# 114    2014
# 115    2015
# 116    2016
# 117    2017
# 118    2018
# Name: Year, Length: 119, dtype: int64

# %%
flattened.head(2)
# Out:
#    Year  1-4 Years  10-14 Years  15-19 Years  5-9 Years
# 0  1900     1983.8        298.3        484.8      466.1
# 1  1901     1695.0        273.6        454.4      427.6

# %%
flattened = flattened.drop('5-9 Years', 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-4ed5aa70b7fe> in <module>()
# ----> 1 flattened = flattened.drop('5-9 Years', 1)
#
# /home/bwood/anaconda3/envs/jup1/lib/python3.5/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /home/bwood/anaconda3/envs/jup1/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
flattened
# Out:
#      Year  1-4 Years  10-14 Years  15-19 Years
# 0    1900     1983.8        298.3        484.8
# 1    1901     1695.0        273.6        454.4
# 2    1902     1655.7        252.5        421.5
# 3    1903     1542.1        268.2        434.1
# 4    1904     1591.5        305.2        471.4
# 5    1905     1498.9        279.8        439.3
# 6    1906     1580.0        272.2        445.2
# 7    1907     1468.3        265.8        437.7
# 8    1908     1396.8        247.9        397.7
# 9    1909     1348.9        230.5        363.6
# 10   1910     1397.3        235.9        371.9
# 11   1911     1176.0        222.2        366.0
# 12   1912     1094.1        202.2        347.2
# 13   1913     1193.4        214.8        360.3
# 14   1914     1024.2        207.2        340.5
# 15   1915      924.2        196.7        330.9
# 16   1916     1111.5        205.1        355.8
# 17   1917     1066.0        218.9        380.3
# 18   1918     1573.5        375.1        777.4
# ...

# %%
mrates.head(10)
# Out:
#    Year  Age Group  Death Rate
# 0  1900  1-4 Years      1983.8
# 1  1901  1-4 Years      1695.0
# 2  1902  1-4 Years      1655.7
# 3  1903  1-4 Years      1542.1
# 4  1904  1-4 Years      1591.5
# 5  1905  1-4 Years      1498.9
# 6  1906  1-4 Years      1580.0
# 7  1907  1-4 Years      1468.3
# 8  1908  1-4 Years      1396.8
# 9  1909  1-4 Years      1348.9

# %%
mrates.Year.nunique()
# Out:
# 119

# %%
mrates.Year.count()
# Out:
# 476

# %%
mrates.groupby('Year')['Death Rate'].mean()
# Out:
# Year
# 1900    808.250
# 1901    712.650
# 1902    683.250
# 1903    664.775
# 1904    698.275
# 1905    653.575
# 1906    668.700
# 1907    634.350
# 1908    599.150
# 1909    568.300
# 1910    588.375
# 1911    518.550
# 1912    482.750
# 1913    521.550
# 1914    465.875
# 1915    428.100
# 1916    488.700
# 1917    488.975
# 1918    793.475
# 1919    475.725
# 1920    478.800
# 1921    404.750
# 1922    371.950
# 1923    390.175
# 1924    349.550
# 1925    336.875
# 1926    354.025
# 1927    314.075
# 1928    335.550
# 1929    324.125
#          ...
# 1989     46.800
# 1990     45.725
# 1991     45.800
# 1992     42.950
# 1993     44.175
# 1994     43.175
# 1995     41.750
# 1996     39.475
# 1997     37.400
# 1998     35.575
# 1999     35.025
# 2000     33.900
# 2001     33.525
# 2002     33.250
# 2003     32.725
# 2004     32.100
# 2005     31.500
# 2006     30.575
# 2007     30.000
# 2008     28.250
# 2009     26.725
# 2010     25.425
# 2011     25.375
# 2012     24.700
# ...

# %%
# %whos
# Out:
# Variable       Type         Data/Info
# -------------------------------------
# df_columns     list         n=3
# df_data        list         n=2
# flattened      DataFrame         Year  1-4 Years  10-<...>n\n[119 rows x 4 columns]
# mrates         DataFrame         Year    Age Group  D<...>n\n[476 rows x 3 columns]
# pd             module       <module 'pandas' from '/h<...>ages/pandas/__init__.py'>
# rates_wide     DataFrame    Age Group  1-4 Years  10-<...>n\n[119 rows x 4 columns]
# sales          DataFrame                             <...>\n[100 rows x 14 columns]
# sales_sorted   DataFrame                             <...>\n[100 rows x 14 columns]
# scratch        DataFrame       Year  Age Group  Death<...>01  1-4 Years      1695.0
# scratch2       DataFrame       Year  Age Group  Death<...>01  1-4 Years      1695.0
# x              DataFrame               country       <...>  Angola        Household

# %%
sales.columns
# Out:
# Index(['region', 'country', 'item_type', 'sales_channel', 'order_priority',
#        'order_date', 'order_id', 'ship_date', 'units_sold', 'unit_price',
#        'unit_cost', 'total_revenue', 'total_cost', 'total_profit'],
#       dtype='object')

# %%
sales.groupby('region')[['units_sold', 'unit_price']].mean()
# Out:
#                                     units_sold  unit_price
# region
# Asia                               5451.545455  335.809091
# Australia and Oceania              6211.363636  222.672727
# Central America and the Caribbean  5110.142857  243.172857
# Europe                             4459.863636  328.979545
# Middle East and North Africa       4867.800000  241.506000
# North America                      6381.000000  277.243333
# Sub-Saharan Africa                 5079.722222  259.618889
