# %% [markdown]
# # Fetch data from a MySQL database into a Dataframe.

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
db_connection_str = 'mysql+pymysql://pythonuser:c0ncordia@127.0.0.1/Sales'
db_connection = create_engine(db_connection_str)

# %%
df = pd.read_sql('SELECT * FROM Customer', con=db_connection)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /home/bwood/anaconda3/envs/jup1/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /home/bwood/anaconda3/envs/jup1/lib/python3.5/site-packages/sqlalchemy/pool.py in connect(self)
#     402         if not self._use_threadlocal:
# --> 403             return _ConnectionFairy._checkout(self)
#     404
#
# /home/bwood/anaconda3/envs/jup1/lib/python3.5/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     790         if not fairy:
# --> 791             fairy = _ConnectionRecord.checkout(pool)
#     792
#
# /home/bwood/anaconda3/envs/jup1/lib/python3.5/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# ...
